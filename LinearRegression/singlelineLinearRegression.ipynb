# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.linear_model import LinearRegression

# %%
data = pd.read_csv("Book.csv")

# %%
data
# Out:
#   Unnamed: 0  videos  views
# 0   channel1      30  34000
# 1   channel2      40  41000
# 2   channel3      50  42500
# 3   channel4      60  54300
# 4   channel5      70  56000

# %%
plt.scatter(data.videos,data.views,color= "red")
plt.xlabel("no of videos")
plt.ylabel("no of views")
plt.title("Youtube video scatter plot")
m,c = np.polyfit(x,y,1)
plt.plot(x,m*x+c)

# %%
data.videos
# Out:
# 0    30
# 1    40
# 2    50
# 3    60
# 4    70
# Name: videos, dtype: int64

# %%
data.views
# Out:
# 0    34000
# 1    41000
# 2    42500
# 3    54300
# 4    56000
# Name: views, dtype: int64

# %%
x = np.array(data.videos)
x
# Out:
# array([30, 40, 50, 60, 70])

# %%
y = np.array(data.views)

# %%
y
# Out:
# array([34000, 41000, 42500, 54300, 56000])

# %%
model = LinearRegression()
model.fit(x.reshape(-1,1),y)
# Out:
# LinearRegression()

# %%
new_x = np.array([52]).reshape(-1,1)
new_x
# Out:
# array([[52]])

# %%
pred = model.predict(new_x)
pred
# Out:
# array([46706.])

# %%
m
# Out:
# np.float64(572.9999999999997)

# %%
c
# Out:
# np.float64(16910.00000000002)

# %%
y_new = m*52 + c

# %%
y_new
# Out:
# np.float64(46706.0)
